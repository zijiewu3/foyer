# %%
import parmed as pmd
from foyer import Forcefield
import mbuild as mb

#Create topology in mbuild
import py3Dmol
from ONA_1_2 import *
test_box = ONA_box(['AAC','GTAC'],[1,1,2])

# %%
#Visualize the structure
test_box.visualize()
# Out:
# <div id="3dmolviewer_15693544771702132"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_15693544771702132" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_15693544771702132 = null;
# var warn = document.getElementById("3dmolwarning_15693544771702132");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_15693544771702132 = $3Dmol.createViewer($("#3dmolviewer_15693544771702132"),{backgroundColor:"white"});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000025, "y": 1.2599999999999996, "z": 5.0}, "radius": 0.5, "color": "0x696969", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": 0.18499999999999975, "y": 1.2599999999999996, "z": 5.0}, "radius": 0.22, "color": "0x2f4f4f", "alpha": 0.9});
# 	viewer_15693544771702132.addSphere({"center": {"x": -0.18500000000000016, "y": 0.4199999999999998, "z": 5.0}, "radius": 0.5, "color": "0xdaa520", "alp
# <div id="3dmolviewer_15693544771898913"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_15693544771898913" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_15693544771898913 = null;
# var warn = document.getElementById("3dmolwarning_15693544771898913");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_15693544771898913 = $3Dmol.createViewer($("#3dmolviewer_15693544771898913"),{backgroundColor:"white"});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000008, "y": 0.8399999999999997, "z": -1.1741129089477747e-16}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.8399999999999997, "z": -1.1330368653550342e-16}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.185, "y": 0.0, "z": -6.654982425258972e-17}, "radius": 0.5, "color": "0xff0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999991, "y": 0.0, "z": -2.316443020291728e-17}, "radius": 0.22, "color": "0x8b0000", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18499999999999983, "y": -0.8399999999999997, "z": 7.839468257077877e-17}, "radius": 0.5, "color": "0x4bd1cc", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.1850000000000002, "y": -0.8399999999999997, "z": 2.420345493150091e-16}, "radius": 0.22, "color": "0x008b8b", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000025, "y": 1.2599999999999996, "z": 5.0}, "radius": 0.5, "color": "0x696969", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": 0.18499999999999975, "y": 1.2599999999999996, "z": 5.0}, "radius": 0.22, "color": "0x2f4f4f", "alpha": 0.9});
# 	viewer_15693544771898913.addSphere({"center": {"x": -0.18500000000000016, "y": 0.4199999999999998, "z": 5.0}, "radius": 0.5, "color": "0xdaa520", "alp

# %%
#Create forcefield in foyer
cgff = Forcefield(forcefield_files='ONA.xml')
#apply it to the mbuild structure
test_box_typed =cgff.apply(test_box,assert_dihedral_params=False)
#Output a LAMMPS data file
mb.formats.lammpsdata.write_lammpsdata(test_box_typed,'test_output.lammps',atom_style='molecular')
# Out:
# No urey bradley terms detected, will use angle_style harmonic
# Charmm dihedrals detected, will use dihedral_style charmm
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _BBA
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _BBC
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _BBG
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _BBT
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _HBA
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _HBC
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _HBG
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:399: UserWarning: Non-atomistic element type detected. Creating custom element for _HBT
#   'Creating custom element for {}'.format(element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_BBA pos=(-0.1850, 0.8400,-0.0000), 0 bonds, id: 140075617108376>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_HBA pos=( 0.1850, 0.8400,-0.0000), 0 bonds, id: 140075617110560>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_BBC pos=(-0.1850,-0.8400, 0.0000), 0 bonds, id: 140075638383672>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_HBC pos=( 0.1850,-0.8400, 0.0000), 0 bonds, id: 140075557858328>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_BBG pos=(-0.1850, 1.2600, 5.0000), 0 bonds, id: 140075617108936>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_HBG pos=( 0.1850, 1.2600, 5.0000), 0 bonds, id: 140075557858832>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_BBT pos=(-0.1850, 0.4200, 5.0000), 0 bonds, id: 140075557856984>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/mbuild/mbuild/compound.py:2304: UserWarning: Guessing that "<_HBT pos=( 0.1850, 0.4200, 5.0000), 0 bonds, id: 140075557907704>" is element: "EP"
#   atom, element))
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:252: UserWarning: Parameters have not been assigned to all proper dihedrals. Total system dihedrals: 12, Parameterized dihedrals: 5. Note that if your system contains torsions of Ryckaert-Bellemans functional form, all of these torsions are processed as propers.
#   warnings.warn(msg)
# /home/zijiewu/mosdef_git/foyer/foyer/forcefield.py:252: UserWarning: Parameters have not been assigned to all impropers. Total system impropers: 3, Parameterized impropers: 0. Note that if your system contains torsions of Ryckaert-Bellemans functional form, all of these torsions are processed as propers
#   warnings.warn(msg)
